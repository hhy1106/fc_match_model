# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'  # 设置中文显示
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('/Users/admin/documents/github/fc_match_model/a14_data/Col_phy.csv')
df.shape#输出数据规模 119957行 18列
# Out:
# (119957, 18)

# %%
df = df.sample(frac=0.3,random_state=None).reset_index()
df.head()
# Out:
#    index                   时间       用户ID       姓名           账号     group1  \
# 0  34350  2022-03-29 16:12:40  191960724   \t洪愿\t  20211004671  \t自动化学院\t
# 1  31132  2022-03-27 10:58:11  191960801  \t徐天楷\t  20211001841  \t自动化学院\t
# 2  35022  2022-03-30 08:20:55  191961551   \t李想\t  20211002431  \t自动化学院\t
# 3  67731  2022-05-04 20:15:05  191960847  \t李沛恒\t  20211001410  \t自动化学院\t
# 4  69077  2022-05-05 17:07:18  191961355   \t戴钺\t  20211004012  \t自动化学院\t
#
#      group2  group3        事件类型       课程id     课程名          班级名        班级id  \
# 0  \t自动化类\t  23Z215  \t学生访问章节\t  222668992  大学物理A1  大学物理A1-0009  50655126.0
# 1  \t自动化类\t  23Z218  \t学生访问章节\t  222668992  大学物理A1  大学物理A1-0010  50655128.0
# 2  \t自动化类\t  23Z215  \t学生访问章节\t  222668992  大学物理A1  大学物理A1-0009  50655126.0
# 3  \t自动化类\t  23Z212  \t学生访问章节\t  222668992  大学物理A1  大学物理A1-0008  50655129.0
# 4  \t自动化类\t  23Z215  \t学生访问章节\t  222668992  大学物理A1  大学物理A1-0009  50655126.0
#
#   任务点类型 任务点名称               设备              IP  省份  城市
# 0   NaN   NaN  \tandroid-app\t     59.71.241.1 NaN NaN
# 1   NaN   NaN  \tandroid-app\t     58.19.3.205 NaN NaN
# 2   NaN   NaN      \tios-app\t  219.139.249.23 NaN NaN
# 3   NaN   NaN  \tandroid-app\t   61.242.130.61 NaN NaN
# 4   NaN   NaN  \tandroid-app\t  61.242.129.206 NaN NaN

# %%
# 查看是否存在缺失值
df.isnull().sum()
# Out:
# index         0
# 时间            0
# 用户ID          0
# 姓名            0
# 账号            0
# group1        0
# group2        0
# group3        0
# 事件类型          0
# 课程id          0
# 课程名           0
# 班级名          21
# 班级id         21
# 任务点类型     29644
# 任务点名称     26274
# 设备         3161
# IP         3182
# 省份        35987
# 城市        35987
# dtype: int64
